# %%
# Name: Your Name
# Course: Data Mining / Data Analytics
# Lab Assignment: Data Visualization, Preprocessing, and Statistical Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../project/heart.csv")
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
plt.scatter(df['age'], df['chol'])
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.title("Age vs Cholesterol")
plt.show()

# %%
plt.hist(df['age'], bins=10)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution")
plt.show()

# %%
sns.boxplot(x=df['chol'])
plt.title("Cholesterol Box Plot")
plt.show()

# %%
df.isnull().sum()
df['chol'] = df['chol'].fillna(df['chol'].mean())

# %%
Q1 = df['chol'].quantile(0.25)
Q3 = df['chol'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['chol'] < lower) | (df['chol'] > upper)]
outliers
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 28    65    0   2     140   417    1        0       157     0      0.8    2
# 85    67    0   2     115   564    0        0       160     0      1.6    1
# 96    62    0   0     140   394    0        0       157     0      1.2    1
# 220   63    1   0     150   407    0        0       154     0      4.0    1
# 246   56    0   0     134   409    0        0       150     1      1.9    1
#
#      caa  thall  output
# 28     1      2       1
# 85     0      3       1
# 96     0      2       1
# 220    3      3       0
# 246    2      3       0

# %%
df = df[(df['chol'] >= lower) & (df['chol'] <= upper)]

# %%
sample_df = df.sample(frac=0.5)
sample_df.head()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 179   57    1   0     150   276    0        0       112     1      0.6    1
# 199   65    1   0     110   248    0        0       158     0      0.6    2
# 44    39    1   2     140   321    0        0       182     0      0.0    2
# 67    45    0   1     130   234    0        0       175     0      0.6    1
# 53    44    0   2     108   141    0        1       175     0      0.6    1
#
#      caa  thall  output
# 179    1      1       0
# 199    2      1       0
# 44     0      2       1
# 67     0      2       1
# 53     0      2       1

# %%
df_reduced = df.drop(columns=['fbs'])
df_reduced.head()
# Out:
#    age  sex  cp  trtbps  chol  restecg  thalachh  exng  oldpeak  slp  caa  \
# 0   60    1   3     145   233        0       150     0      2.3    0    0
# 1   35    1   2     130   250        1       187     0      3.5    0    0
# 2   41    0   1     130   204        0       172     0      1.4    2    0
# 3   55    1   1     120   236        1       178     0      0.8    2    0
# 4   56    0   0     120   354        1       163     1      0.6    2    0
#
#    thall  output
# 0      1       1
# 1      2       1
# 2      2       1
# 3      2       1
# 4      2       1

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df['chol_scaled'] = scaler.fit_transform(df[['chol']])
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output  chol_scaled
# 0    0      1       1     0.457265
# 1    0      2       1     0.529915
# 2    0      2       1     0.333333
# 3    0      2       1     0.470085
# 4    0      2       1     0.974359

# %%
df['age_group'] = pd.cut(df['age'], bins=3, labels=["Young","Middle","Old"])
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output  chol_scaled age_group
# 0    0      1       1     0.457265    Middle
# 1    0      2       1     0.529915     Young
# 2    0      2       1     0.333333     Young
# 3    0      2       1     0.470085    Middle
# 4    0      2       1     0.974359    Middle

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284 entries, 0 to 288
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          284 non-null    int64
#  1   sex          284 non-null    int64
#  2   cp           284 non-null    int64
#  3   trtbps       284 non-null    int64
#  4   chol         284 non-null    int64
#  5   fbs          284 non-null    int64
#  6   restecg      284 non-null    int64
#  7   thalachh     284 non-null    int64
#  8   exng         284 non-null    int64
#  9   oldpeak      284 non-null    float64
#  10  slp          284 non-null    int64
#  11  caa          284 non-null    int64
#  12  thall        284 non-null    int64
#  13  output       284 non-null    int64
#  14  chol_scaled  284 non-null    float64
#  15  age_group    284 non-null    category
# dtypes: category(1), float64(2), int64(13)
# memory usage: 35.9 KB
# ...

# %%
print("Minimum:", df['chol'].min())
print("Maximum:", df['chol'].max())
print("Mean:", df['chol'].mean())
print("Median:", df['chol'].median())
print("Mode:", df['chol'].mode())
# Out:
# Minimum: 126
# Maximum: 360
# Mean: 244.61267605633802
# Median: 242.5
# Mode: 0    204
# 1    234
# Name: chol, dtype: int64

# %%
range_val = df['chol'].max() - df['chol'].min()

print("Range:", range_val)
print("Variance:", df['chol'].var())
print("Standard Deviation:", df['chol'].std())
print("Quartiles:\n", df['chol'].quantile([0.25,0.5,0.75]))
# Out:
# Range: 234
# Variance: 1987.6727716120045
# Standard Deviation: 44.583323918389084
# Quartiles:
#  0.25    212.0
# 0.50    242.5
# 0.75    274.0
# Name: chol, dtype: float64

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
# /var/folders/xs/_xb9qh5j20x8dmf2xcbx07z40000gp/T/ipykernel_2691/2355143037.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
#                   age       sex        cp    trtbps      chol       fbs  \
# age          1.000000 -0.108756 -0.059911  0.268466  0.200863  0.103117
# sex         -0.108756  1.000000 -0.057768 -0.056772 -0.149492  0.039926
# cp          -0.059911 -0.057768  1.000000  0.085778 -0.142173  0.126866
# trtbps       0.268466 -0.056772  0.085778  1.000000  0.174117  0.146438
# chol         0.200863 -0.149492 -0.142173  0.174117  1.000000  0.026086
# fbs          0.103117  0.039926  0.126866  0.146438  0.026086  1.000000
# restecg     -0.109184 -0.063683  0.049002 -0.086545 -0.112872 -0.068519
# thalachh    -0.406024 -0.049336  0.274085 -0.036586 -0.065509  0.010160
# ...

# %%
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
